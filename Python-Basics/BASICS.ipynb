# %%
s1='how r u?'
s2="I am fine"
s3='''he said raju is good boy'''
print(s1)
print(s2)
print(s3)
# Out:
# how r u?
# I am fine
# he said raju is good boy

# %% [markdown]
# escape char

# %%
#\n->to make new line
print("hi \nhello")
#\t -> to give tab space
print("hi \thello")
# Out:
# hi
# hello
# hi 	hello
